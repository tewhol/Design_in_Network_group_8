# %%
# !pip install networkx 
# If networkX is not yet installed, this installs it.
# Out:
# Requirement already satisfied: networkx in c:\users\timew\pycharmprojects\design_in_network_group_8_interpreter\lib\site-packages (3.2.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import Libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Read in the excel file 'ex-length.xlsx' as a dataframe
networkL = pd.read_excel('ex-length.xlsx')
# Make it a directional graph (see option 'create_using')'
nw_graph_l = nx.from_pandas_edgelist(networkL,'From', 'To', ['weight'], create_using=nx.DiGraph)

# %%
# Read in the excel file 'ex-traveltime.xlsx' as a dataframe
networkT = pd.read_excel('ex-traveltime.xlsx')
# Make it a directional graph
nw_graph_tt = nx.from_pandas_edgelist(networkT,'From', 'To', ['weight'], create_using=nx.DiGraph)

# %%
# Drawing the graph and finding the shortest path
print(f'is directed: {nx.is_directed(nw_graph_tt)}')
nx.draw(nw_graph_tt, with_labels=True)
print(f'shortest path between A and I: {nx.shortest_path_length(nw_graph_tt,'A','I')}')

# Finding the pagerank and edge betweenness
pagerank_values_tt = nx.pagerank(nw_graph_tt)
edge_betweenness_tt = nx.edge_betweenness_centrality(nw_graph_l, weight='weight')

# Printing all these values
for node,value in pagerank_values_tt.items():
    print(f'Node: {node} with pagerank: {value}')
print('\n')
for edge,value in edge_betweenness_tt.items():
    print(f'Edge {edge}, pagerank: {value}')
# Out:
# is directed: True
# shortest path between A and I: 4
# Node: A with pagerank: 0.020447633166560487
# Node: B with pagerank: 0.09985234737956689
# Node: C with pagerank: 0.11553131576889963
# Node: D with pagerank: 0.0400341910980604
# Node: E with pagerank: 0.11864809356681211
# Node: F with pagerank: 0.020447633166560487
# Node: G with pagerank: 0.27367007616450734
# Node: H with pagerank: 0.13210591544506853
# Node: I with pagerank: 0.17926279424396402
#
#
# Edge ('A', 'B'), pagerank: 0.027777777777777776
# Edge ('A', 'C'), pagerank: 0.06944444444444445
# Edge ('B', 'C'), pagerank: 0.16666666666666666
# Edge ('B', 'D'), pagerank: 0.1111111111111111
# Edge ('C', 'E'), pagerank: 0.3194444444444444
# Edge ('E', 'G'), pagerank: 0.3055555555555555
# Edge ('F', 'C'), pagerank: 0.09722222222222221
# Edge ('G', 'B'), pagerank: 0.2638888888888889
# Edge ('G', 'H'), pagerank: 0.09722222222222221
# Edge ('G', 'I'), pagerank: 0.08333333333333333
# Edge ('H', 'I'), pagerank: 0.08333333333333333
# Edge ('I', 'G'), pagerank: 0.15277777777777776

# %%
# Directed and shortest path
print(f'is directed: {nx.is_directed(nw_graph_l)}')
nx.draw(nw_graph_l, with_labels=True)
print(f'shortest path between A and I: {nx.shortest_path_length(nw_graph_l,'A','I')}')

# Finding the pagerank and adding these as attributes
pagerank_values_l = nx.pagerank(nw_graph_l)
nx.set_node_attributes(nw_graph_l,pagerank_values_l, "Pagerank")

# Finding the edge betweenness and adding these as attributes
edge_betweenness_l = nx.edge_betweenness_centrality(nw_graph_l, weight='weight')
print(edge_betweenness_l)
nx.set_edge_attributes(nw_graph_l,edge_betweenness_l, 'betweenness')

# Printing these values
for node,value in pagerank_values_l.items():
    print(f'Node: {node}, pagerank: {value}')
print('\n')
for edge,value in edge_betweenness_l.items():
    print(f'Edge: {edge}, betweenness: {value}')
    
# Creating a graph file that can also be used by Gephi as test (a graphx file)
nx.write_gexf(nw_graph_l, "ex_length_modified.gexf")
# Out:
# is directed: True
# shortest path between A and I: 4
# {('A', 'B'): 0.027777777777777776, ('A', 'C'): 0.06944444444444445, ('B', 'C'): 0.16666666666666666, ('B', 'D'): 0.1111111111111111, ('C', 'E'): 0.3194444444444444, ('E', 'G'): 0.3055555555555555, ('F', 'C'): 0.09722222222222221, ('G', 'B'): 0.2638888888888889, ('G', 'H'): 0.09722222222222221, ('G', 'I'): 0.08333333333333333, ('H', 'I'): 0.08333333333333333, ('I', 'G'): 0.15277777777777776}
# Node: A, pagerank: 0.018824531639885442
# Node: B, pagerank: 0.08756825514731159
# Node: C, pagerank: 0.11483588849686291
# Node: D, pagerank: 0.02284796052395632
# Node: E, pagerank: 0.11643548297154274
# Node: F, pagerank: 0.018824531639885442
# Node: G, pagerank: 0.28290488028239963
# Node: H, pagerank: 0.14351130296186917
# Node: I, pagerank: 0.19424716633628664
#
#
# Edge: ('A', 'B'), betweenness: 0.027777777777777776
# Edge: ('A', 'C'), betweenness: 0.06944444444444445
# Edge: ('B', 'C'), betweenness: 0.16666666666666666
# Edge: ('B', 'D'), betweenness: 0.1111111111111111
# Edge: ('C', 'E'), betweenness: 0.3194444444444444
# Edge: ('E', 'G'), betweenness: 0.3055555555555555
# Edge: ('F', 'C'), betweenness: 0.09722222222222221
# Edge: ('G', 'B'), betweenness: 0.2638888888888889
# Edge: ('G', 'H'), betweenness: 0.09722222222222221
# Edge: ('G', 'I'), betweenness: 0.08333333333333333
# Edge: ('H', 'I'), betweenness: 0.08333333333333333
# Edge: ('I', 'G'), betweenness: 0.15277777777777776
